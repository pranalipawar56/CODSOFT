# %%
#importing pandas 
import pandas as pd

# %%
#reading a dataset
df=pd.read_csv("E:\\Users\\GEONIX\\Documents\\Sales.csv")

# %%
#handeling missing values
df.isnull().sum
df.dropna()
# Out:
#           Date  Day      Month  Year  Customer_Age             Age_Group  \
# 0   11/26/2013   26   November  2013            19           Youth (<25)
# 1   11/26/2015   26   November  2015            19           Youth (<25)
# 2    3/23/2014   23      March  2014            49        Adults (35-64)
# 3    3/23/2016   23      March  2016            49        Adults (35-64)
# 4    5/15/2014   15        May  2014            47        Adults (35-64)
# ..         ...  ...        ...   ...           ...                   ...
# 94   9/23/2013   23  September  2013            41        Adults (35-64)
# 95   9/23/2015   23  September  2015            41        Adults (35-64)
# 96   9/20/2013   20  September  2013            32  Young Adults (25-34)
# 97   9/20/2015   20  September  2015            32  Young Adults (25-34)
# 98  10/25/2013   25    October  2013            32  Young Adults (25-34)
#
#    Customer_Gender        Country             State Product_Category  \
# ...

# %%
#remove duplicates
df=df.drop_duplicates()

# %%
#standerdize text fields
df['Customer_Gender']=df['Customer_Gender'].str.lower().str.strip()
df['Country']=df['Country'].str.title

# %%
#format dates
df['Date']=pd.to_datetime(df['Date'],dayfirst=True)
# Out:
# C:\Users\GEONIX\AppData\Local\Temp\ipykernel_13440\2358700828.py:2: UserWarning: Parsing dates in %m/%d/%Y format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   df['Date']=pd.to_datetime(df['Date'],dayfirst=True)

# %%
#for refrence to original column names 
print(df.columns)
# Out:
# Index(['Date', 'Day', 'Month', 'Year', 'Customer_Age', 'Age_Group',
#        'Customer_Gender', 'Country', 'State', 'Product_Category',
#        'Sub_Category', 'Product', 'Order_Quantity', 'Unit_Cost', 'Unit_Price',
#        'Profit', 'Cost', 'Revenue'],
#       dtype='object')

# %%
df['Customer_Age']=df['Customer_Age'].astype(int)

# %%
print(df['Customer_Age'].dtype)
# Out:
# int32
